# %% [markdown]
# # Data Preprocessing for Machine Learning
#
# Welcome to the data preprocessing tutorial! This notebook builds on your Pandas knowledge from `02_course_introduction.ipynb` and prepares you for machine learning.
#
# ## What is Data Preprocessing?
#
# Data preprocessing is the process of **transforming raw data into a clean, usable format** for machine learning algorithms. Real-world data is rarely perfect:
#
# - **Missing values**: Some observations may be incomplete
# - **Inconsistent formats**: Dates, categories, or numbers may be stored incorrectly
# - **Outliers**: Extreme values that could skew results
# - **Wrong scale**: Features with different ranges (e.g., age 0-100 vs income 0-1,000,000)
# - **Categorical data**: Text labels that algorithms can't process directly
#
# **Why is it important?**
# - Machine learning algorithms require numeric data in consistent formats
# - Poor preprocessing leads to poor model performance
# - Data scientists spend 60-80% of their time on data preprocessing!
#
# ## About This Dataset
#
# We'll use the **Melbourne Housing Market** dataset containing residential property sales data. This is perfect for learning preprocessing because it has:
# - Missing values
# - Categorical variables
# - Numerical features at different scales
# - Real-world data quality issues
#
# [Dataset source and descriptions](https://www.kaggle.com/datasets/anthonypino/melbourne-housing-market/data)

# %% [markdown]
# ---
# ## Step 1: Load and Explore the Data
#
# First, let's load our libraries and data.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set visualization style
sns.set_style('whitegrid')
# %matplotlib inline

# %%
# Load the dataset
data_root = "https://raw.githubusercontent.com/LuWidme/uk259/main/"
df = pd.read_csv(data_root + "datasets/melb_data.csv")

# Add a categorical feature for demonstration
np.random.seed(42)  # For reproducibility
df["Yard"] = np.random.choice(["none", "small", "medium", "large"], df.shape[0])

print(f"Dataset loaded: {df.shape[0]} rows and {df.shape[1]} columns")
df.head()
# Out:
# Dataset loaded: 13580 rows and 22 columns
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5    3067.0  ...  1.0     202.0           NaN        NaN
# 1  4/02/2016       2.5    3067.0  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5    3067.0  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5    3067.0  ...  1.0      94.0           NaN        NaN
# 4  4/06/2016       2.5    3067.0  ...  2.0     120.0         142.0     2014.0
#
# ...

# %% [markdown]
# ### Initial Data Exploration
#
# Before preprocessing, we need to **understand our data**. Let's check:
# 1. The shape and column names
# 2. Data types of each column
# 3. Basic statistics
# 4. Missing values

# %%
# 1. Shape and columns
print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (13580, 22)
#
# Columns:
# ['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount', 'Yard']

# %%
# 2. Data types
print("Data Types:")
print(df.dtypes)
# Out:
# Data Types:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# Yard              object
# dtype: object

# %%
# 3. Basic statistics
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  13580.000000  1.358000e+04  13580.000000  13580.000000  13580.000000
# mean       2.937997  1.075684e+06     10.137776   3105.301915      2.914728
# std        0.955748  6.393107e+05      5.868725     90.676964      0.965921
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.500000e+05      6.100000   3044.000000      2.000000
# 50%        3.000000  9.030000e+05      9.200000   3084.000000      3.000000
# 75%        3.000000  1.330000e+06     13.000000   3148.000000      3.000000
# max       10.000000  9.000000e+06     48.100000   3977.000000     20.000000
#
#            Bathroom           Car       Landsize  BuildingArea    YearBuilt  \
# count  13580.000000  13518.000000   13580.000000   7130.000000  8205.000000
# mean       1.534242      1.610075     558.416127    151.967650  1964.684217
# ...

# %%
# 4. Missing values count
print("Missing Values per Column:")
missing = df.isnull().sum()
print(missing[missing > 0])  # Show only columns with missing values

print(f"\nTotal rows with at least one missing value: {df.isnull().any(axis=1).sum()}")
# Out:
# Missing Values per Column:
# Car               62
# BuildingArea    6450
# YearBuilt       5375
# CouncilArea     1369
# dtype: int64
#
# Total rows with at least one missing value: 7384

# %% [markdown]
# **Observations:**
# - `BuildingArea` has ~6,450 missing values (47%)
# - `YearBuilt` has ~5,375 missing values (40%)
# - `CouncilArea` has ~1,369 missing values (10%)
# - `Car` has 62 missing values (<1%)
#
# We'll need different strategies for each!

# %% [markdown]
# ### Visualizing the Data Distribution
#
# Visualizations help us understand the data better.

# %%
# Price distribution
plt.figure(figsize=(10, 4))
sns.histplot(df["Price"], bins=50, kde=True)
plt.title("Distribution of House Prices")
plt.xlabel("Price ($)")
plt.ylabel("Frequency")
plt.show()

print(f"Price range: ${df['Price'].min():,.0f} to ${df['Price'].max():,.0f}")
print(f"Median price: ${df['Price'].median():,.0f}")
# Out:
# Price range: $85,000 to $9,000,000
# Median price: $903,000

# %%
# Regional distribution
plt.figure(figsize=(12, 5))
sns.countplot(data=df, x='Regionname', order=df['Regionname'].value_counts().index)
plt.title("Number of Properties by Region")
plt.xlabel("Region")
plt.ylabel("Count")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Step 2: Handling Missing Values
#
# Missing values are one of the most common data quality issues. There are several strategies:
#
# ### Strategy 1: Remove Rows or Columns
#
# **When to use:**
# - Column has too many missing values (>50%) and isn't critical
# - Row has missing values in critical columns
#
# **Pandas method:** `dropna()`

# %%
# Example: Drop rows with ANY missing values
df_dropped = df.dropna()
print(f"Original: {df.shape[0]} rows")
print(f"After dropna(): {df_dropped.shape[0]} rows")
print(f"Rows removed: {df.shape[0] - df_dropped.shape[0]} ({(1 - df_dropped.shape[0]/df.shape[0])*100:.1f}%)")
# Out:
# Original: 13580 rows
# After dropna(): 6196 rows
# Rows removed: 7384 (54.4%)
# Original: 13580 rows
# After dropna(): 6196 rows
# Rows removed: 7384 (54.4%)

# %% [markdown]
# **Warning:** We lost over 50% of our data! This is too much. Let's use a smarter approach.

# %%
# Better: Only drop rows where PRICE is missing (our target variable)
df_cleaned = df.dropna(subset=['Price'])
print(f"Rows after dropping missing prices: {df_cleaned.shape[0]}")
print(f"Rows removed: {df.shape[0] - df_cleaned.shape[0]}")
# Out:
# Rows after dropping missing prices: 13580
# Rows removed: 0
# Rows after dropping missing prices: 13580
# Rows removed: 0

# %% [markdown]
# ### Strategy 2: Fill Missing Values
#
# Instead of removing data, we can **impute** (fill) missing values.
#
# **Common fill strategies:**
# - **Mean/Median**: For numerical data (median is better for skewed distributions)
# - **Mode**: For categorical data (most frequent value)
# - **Fixed value**: Sometimes 0, "Unknown", or a domain-specific value makes sense
# - **Forward/Backward fill**: For time series data

# %%
# Create a copy to work with
df_filled = df.copy()

# Fill 'Car' with median (most houses have 1-2 car spaces)
median_cars = df_filled['Car'].median()
df_filled['Car'].fillna(median_cars, inplace=True)
print(f"Filled 'Car' column with median: {median_cars}")

# Fill 'YearBuilt' with median year
median_year = df_filled['YearBuilt'].median()
df_filled['YearBuilt'].fillna(median_year, inplace=True)
print(f"Filled 'YearBuilt' column with median: {median_year}")

# Fill 'CouncilArea' with mode (most frequent value)
mode_council = df_filled['CouncilArea'].mode()[0]
df_filled['CouncilArea'].fillna(mode_council, inplace=True)
print(f"Filled 'CouncilArea' column with mode: {mode_council}")

# Fill 'BuildingArea' with median (alternative: could use mean)
median_building = df_filled['BuildingArea'].median()
df_filled['BuildingArea'].fillna(median_building, inplace=True)
print(f"Filled 'BuildingArea' column with median: {median_building}")

# Verify
print("\nRemaining missing values:")
print(df_filled.isnull().sum().sum())
# Out:
# Filled 'Car' column with median: 2.0
# Filled 'YearBuilt' column with median: 1970.0
# Filled 'CouncilArea' column with mode: Moreland
# Filled 'BuildingArea' column with median: 126.0
#
# Remaining missing values:
# 0
# C:\Users\liaor\AppData\Local\Temp\ipykernel_78480\630440702.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_filled['Car'].fillna(median_cars, inplace=True)
# ...

# %% [markdown]
# ---
# ## Step 3: Handling Outliers
#
# **Outliers** are extreme values that differ significantly from other observations. They can:
# - Skew statistical analyses
# - Negatively impact model performance
# - Sometimes indicate data errors
#
# **Detection methods:**
# 1. **Visual inspection**: Box plots, scatter plots
# 2. **Statistical**: IQR (Interquartile Range) method, Z-score
# 3. **Domain knowledge**: Does this value make sense?

# %%
# Visualize potential outliers with box plots
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

sns.boxplot(data=df_filled, y='Price', ax=axes[0])
axes[0].set_title('Price Distribution')

sns.boxplot(data=df_filled, y='Landsize', ax=axes[1])
axes[1].set_title('Landsize Distribution')

sns.boxplot(data=df_filled, y='BuildingArea', ax=axes[2])
axes[2].set_title('BuildingArea Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### IQR Method for Outlier Detection
#
# The **Interquartile Range (IQR)** method defines outliers as values that are:
# - Below: Q1 - 1.5 × IQR
# - Above: Q3 + 1.5 × IQR
#
# Where:
# - Q1 = 25th percentile
# - Q3 = 75th percentile
# - IQR = Q3 - Q1

# %%
# ADVANCED: Detect outliers in Price using IQR method
Q1 = df_filled['Price'].quantile(0.25)
Q3 = df_filled['Price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

print(f"Q1 (25th percentile): ${Q1:,.0f}")
print(f"Q3 (75th percentile): ${Q3:,.0f}")
print(f"IQR: ${IQR:,.0f}")
print(f"\nOutlier bounds:")
print(f"Lower: ${lower_bound:,.0f}")
print(f"Upper: ${upper_bound:,.0f}")

# Count outliers
outliers = df_filled[(df_filled['Price'] < lower_bound) | (df_filled['Price'] > upper_bound)]
print(f"\nNumber of price outliers: {len(outliers)} ({len(outliers)/len(df_filled)*100:.1f}%)")
# Out:
# Q1 (25th percentile): $650,000
# Q3 (75th percentile): $1,330,000
# IQR: $680,000
#
# Outlier bounds:
# Lower: $-370,000
# Upper: $2,350,000
#
# Number of price outliers: 612 (4.5%)
# Q1 (25th percentile): $650,000
# Q3 (75th percentile): $1,330,000
# IQR: $680,000
#
# Outlier bounds:
# Lower: $-370,000
# Upper: $2,350,000
#
# Number of price outliers: 612 (4.5%)

# %% [markdown]
# **Note:** Whether to remove outliers depends on your analysis goals. High-priced luxury homes might be legitimate, not errors!

# %% [markdown]
# ---
# ## Step 4: Feature Scaling
#
# Many ML algorithms require features to be on the **same scale**. Compare:
# - `Rooms`: 1-10
# - `Distance`: 0-48 km
# - `Price`: $85,000-$9,000,000
#
# Without scaling, algorithms will treat large numbers as more important!
#
# ### Method 1: Standardization (Z-score normalization)
#
# **Formula:** `z = (x - μ) / σ`
#
# Where:
# - x = original value
# - μ = mean
# - σ = standard deviation
#
# **Result:** Mean = 0, Standard deviation = 1
#
# **When to use:** Most algorithms (Linear Regression, Neural Networks, SVM)

# %%
from sklearn.preprocessing import StandardScaler

# Create a scaler
scaler = StandardScaler()

# Standardize Rooms and Price
df_filled[['Rooms_scaled', 'Price_scaled']] = scaler.fit_transform(df_filled[['Rooms', 'Price']])

# Compare original vs scaled
print("Original values (first 5 rows):")
print(df_filled[['Rooms', 'Price']].head())
print("\nStandardized values (first 5 rows):")
print(df_filled[['Rooms_scaled', 'Price_scaled']].head())

# Verify: mean should be ~0, std should be ~1
print("\nVerification:")
print(f"Rooms_scaled - Mean: {df_filled['Rooms_scaled'].mean():.10f}, Std: {df_filled['Rooms_scaled'].std():.4f}")
print(f"Price_scaled - Mean: {df_filled['Price_scaled'].mean():.10f}, Std: {df_filled['Price_scaled'].std():.4f}")
# Out:
# Original values (first 5 rows):
#    Rooms      Price
# 0      2  1480000.0
# 1      2  1035000.0
# 2      3  1465000.0
# 3      3   850000.0
# 4      4  1600000.0
#
# Standardized values (first 5 rows):
#    Rooms_scaled  Price_scaled
# 0     -0.981463      0.632448
# 1     -0.981463     -0.063640
# 2      0.064876      0.608984
# 3      0.064876     -0.353025
# 4      1.111216      0.820157
#
# Verification:
# Rooms_scaled - Mean: -0.0000000000, Std: 1.0000
# Price_scaled - Mean: 0.0000000000, Std: 1.0000
# Original values (first 5 rows):
#    Rooms      Price
# 0      2  1480000.0
# 1      2  1035000.0
# 2      3  1465000.0
# 3      3   850000.0
# 4      4  1600000.0
#
# Standardized values (first 5 rows):
#    Rooms_scaled  Price_scaled
# 0     -0.981463      0.632448
# 1     -0.981463     -0.063640
# 2      0.064876      0.608984
# 3      0.064876     -0.353025
# 4      1.111216      0.820157
#
# Verification:
# Rooms_scaled - Mean: -0.0000000000, Std: 1.0000
# ...

# %% [markdown]
# **Interpretation of standardized values:**
# - `0`: Exactly at the mean
# - `+1`: One standard deviation above the mean
# - `-1`: One standard deviation below the mean
# - `+2`: Two standard deviations above (quite high)
# - `-2`: Two standard deviations below (quite low)
#
# **Example:** A house with `Price_scaled = -1.0` costs about one standard deviation less than the average house.

# %% [markdown]
# ### Method 2: Normalization (Min-Max Scaling)
#
# **Formula:** `x_norm = (x - x_min) / (x_max - x_min)`
#
# **Result:** Values scaled to range [0, 1]
#
# **When to use:** Neural Networks, algorithms sensitive to outliers

# %%
from sklearn.preprocessing import MinMaxScaler

# Create a normalizer
normalizer = MinMaxScaler()

# Normalize Distance
df_filled[['Distance_normalized']] = normalizer.fit_transform(df_filled[['Distance']])

print("Original Distance (first 5):")
print(df_filled['Distance'].head())
print("\nNormalized Distance (first 5):")
print(df_filled['Distance_normalized'].head())
print(f"\nRange: [{df_filled['Distance_normalized'].min()}, {df_filled['Distance_normalized'].max()}]")
# Out:
# Original Distance (first 5):
# 0    2.5
# 1    2.5
# 2    2.5
# 3    2.5
# 4    2.5
# Name: Distance, dtype: float64
#
# Normalized Distance (first 5):
# 0    0.051975
# 1    0.051975
# 2    0.051975
# 3    0.051975
# 4    0.051975
# Name: Distance_normalized, dtype: float64
#
# Range: [0.0, 0.9999999999999999]
# Original Distance (first 5):
# 0    2.5
# 1    2.5
# 2    2.5
# 3    2.5
# 4    2.5
# Name: Distance, dtype: float64
#
# Normalized Distance (first 5):
# 0    0.051975
# 1    0.051975
# 2    0.051975
# 3    0.051975
# 4    0.051975
# Name: Distance_normalized, dtype: float64
#
# Range: [0.0, 0.9999999999999999]

# %% [markdown]
# **Important question:** Does it make sense to scale certain features?
#
# - **Postcode**: NO - it's a categorical identifier, not a magnitude
# - **Distance**: YES - it's a meaningful numerical measure
# - **Latitude/Longitude**: MAYBE - depends on your use case
#
# Always think about what your features represent!

# %% [markdown]
# ---
# ## Step 5: Encoding Categorical Variables
#
# Machine learning algorithms need **numbers**, not text. We must convert categorical variables.
#
# ### Method 1: Label Encoding
#
# **What it does:** Assigns each category a unique integer (0, 1, 2, ...)
#
# **When to use:**
# - **Ordinal data** (categories with natural order): e.g., "small" < "medium" < "large"
# - Tree-based algorithms (Decision Trees, Random Forests)
#
# **WARNING:** Don't use for nominal data with algorithms that assume order!

# %%
# Label encoding for 'Type' (property type)
df_filled['Type_encoded'] = df_filled['Type'].astype('category').cat.codes

print("Original 'Type' values and their encoded versions:")
print(df_filled[['Type', 'Type_encoded']].drop_duplicates().sort_values('Type_encoded'))
# Out:
# Original 'Type' values and their encoded versions:
#    Type  Type_encoded
# 0     h             0
# 21    t             1
# 8     u             2
# Original 'Type' values and their encoded versions:
#    Type  Type_encoded
# 0     h             0
# 21    t             1
# 8     u             2

# %% [markdown]
# ### Manual Ordinal Encoding
#
# For ordinal variables with known order, we can manually map values:

# %%
# Manual encoding for Yard (none < small < medium < large)
yard_mapping = {'none': 0, 'small': 1, 'medium': 2, 'large': 3}
df_filled['Yard_encoded'] = df_filled['Yard'].map(yard_mapping)

print("Yard encoding:")
print(df_filled[['Yard', 'Yard_encoded']].drop_duplicates().sort_values('Yard_encoded'))
# Out:
# Yard encoding:
#      Yard  Yard_encoded
# 2    none             0
# 9   small             1
# 0  medium             2
# 1   large             3
# Yard encoding:
#      Yard  Yard_encoded
# 2    none             0
# 9   small             1
# 0  medium             2
# 1   large             3

# %% [markdown]
# ### Method 2: One-Hot Encoding
#
# **What it does:** Creates a new binary column for each category
#
# **When to use:**
# - **Nominal data** (no natural order): e.g., colors, regions, names
# - When you have relatively few unique values (<10-15)
#
# **Example:** Region with values [North, South, East] becomes:
# - `Region_North`: 1 if North, else 0
# - `Region_South`: 1 if South, else 0
# - `Region_East`: 1 if East, else 0

# %%
# One-hot encode 'Regionname'
df_encoded = pd.get_dummies(df_filled, columns=['Regionname'], prefix='Region', drop_first=True)

print(f"Original columns: {df_filled.shape[1]}")
print(f"After one-hot encoding: {df_encoded.shape[1]}")
print(f"\nNew binary columns created:")
region_cols = [col for col in df_encoded.columns if col.startswith('Region_')]
print(region_cols)
print("\nSample of one-hot encoded data:")
print(df_encoded[region_cols].head(10))
# Out:
# Original columns: 27
# After one-hot encoding: 33
#
# New binary columns created:
# ['Region_Eastern Victoria', 'Region_Northern Metropolitan', 'Region_Northern Victoria', 'Region_South-Eastern Metropolitan', 'Region_Southern Metropolitan', 'Region_Western Metropolitan', 'Region_Western Victoria']
#
# Sample of one-hot encoded data:
#    Region_Eastern Victoria  Region_Northern Metropolitan  \
# 0                    False                          True
# 1                    False                          True
# 2                    False                          True
# 3                    False                          True
# 4                    False                          True
# 5                    False                          True
# 6                    False                          True
# 7                    False                          True
# 8                    False                          True
# 9                    False                          True
#
# ...

# %% [markdown]
# **Why `drop_first=True`?**
#
# If we have 3 regions and create 3 binary columns, they're perfectly correlated (multicollinearity). If a house is not in North or South, it MUST be in East. We can drop one column and still capture all information.

# %% [markdown]
# ---
# ## Step 6: Feature Engineering
#
# **Feature engineering** means creating new features from existing ones to help models learn better.
#
# Examples:
# - Combine features: `Total_Rooms = Bedroom2 + Bathroom`
# - Extract date parts: Year, Month, Day from a date
# - Create ratios: `Price_per_Room = Price / Rooms`
# - Binning: Group continuous values into categories

# %%
# Example 1: Create a price per room feature
df_filled['Price_per_Room'] = df_filled['Price'] / df_filled['Rooms']

# Example 2: Create age of building
current_year = 2024
df_filled['Building_Age'] = current_year - df_filled['YearBuilt']

# Example 3: Total indoor space
df_filled['Total_Rooms'] = df_filled['Bedroom2'] + df_filled['Bathroom']

print("New engineered features:")
print(df_filled[['Price', 'Rooms', 'Price_per_Room', 'YearBuilt', 'Building_Age', 'Total_Rooms']].head(10))
# Out:
# New engineered features:
#        Price  Rooms  Price_per_Room  YearBuilt  Building_Age  Total_Rooms
# 0  1480000.0      2   740000.000000     1970.0          54.0          3.0
# 1  1035000.0      2   517500.000000     1900.0         124.0          3.0
# 2  1465000.0      3   488333.333333     1900.0         124.0          5.0
# 3   850000.0      3   283333.333333     1970.0          54.0          5.0
# 4  1600000.0      4   400000.000000     2014.0          10.0          4.0
# 5   941000.0      2   470500.000000     1970.0          54.0          3.0
# 6  1876000.0      3   625333.333333     1910.0         114.0          6.0
# 7  1636000.0      2   818000.000000     1890.0         134.0          3.0
# 8   300000.0      1   300000.000000     1970.0          54.0          2.0
# 9  1097000.0      2   548500.000000     1900.0         124.0          4.0
# New engineered features:
#        Price  Rooms  Price_per_Room  YearBuilt  Building_Age  Total_Rooms
# ...

# %% [markdown]
# ### Binning (Discretization)
#
# Convert continuous variables into categories:

# %%
# Create price categories
price_bins = [0, 500000, 1000000, 1500000, float('inf')]
price_labels = ['Budget', 'Mid-Range', 'Premium', 'Luxury']
df_filled['Price_Category'] = pd.cut(df_filled['Price'], bins=price_bins, labels=price_labels)

print("Price category distribution:")
print(df_filled['Price_Category'].value_counts().sort_index())

# Visualize
plt.figure(figsize=(8, 5))
df_filled['Price_Category'].value_counts().sort_index().plot(kind='bar', color='steelblue')
plt.title('Distribution of Houses by Price Category')
plt.xlabel('Price Category')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()
# Out:
# Price category distribution:
# Price_Category
# Budget       1597
# Mid-Range    6240
# Premium      3282
# Luxury       2461
# Name: count, dtype: int64
# Price category distribution:
# Price_Category
# Budget       1597
# Mid-Range    6240
# Premium      3282
# Luxury       2461
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Step 7: Data Type Conversions
#
# Ensure columns have the correct data types for efficient processing.

# %%
# Convert Date column from string to datetime
df_filled['Date'] = pd.to_datetime(df_filled['Date'], format='%d/%m/%Y')

# Now we can extract useful date features
df_filled['Sale_Year'] = df_filled['Date'].dt.year
df_filled['Sale_Month'] = df_filled['Date'].dt.month
df_filled['Sale_DayOfWeek'] = df_filled['Date'].dt.dayofweek  # Monday=0, Sunday=6

print("Date-based features:")
print(df_filled[['Date', 'Sale_Year', 'Sale_Month', 'Sale_DayOfWeek']].head())

# Check if certain months have more sales
print("\nSales by month:")
print(df_filled['Sale_Month'].value_counts().sort_index())
# Out:
# Date-based features:
#         Date  Sale_Year  Sale_Month  Sale_DayOfWeek
# 0 2016-12-03       2016          12               5
# 1 2016-02-04       2016           2               3
# 2 2017-03-04       2017           3               5
# 3 2017-03-04       2017           3               5
# 4 2016-06-04       2016           6               5
#
# Sales by month:
# Sale_Month
# 1        2
# 2      443
# 3      678
# 4      949
# 5     2029
# 6     1830
# 7     1982
# 8     1550
# 9     1845
# 10     551
# 11    1114
# 12     607
# Name: count, dtype: int64
# Date-based features:
#         Date  Sale_Year  Sale_Month  Sale_DayOfWeek
# 0 2016-12-03       2016          12               5
# 1 2016-02-04       2016           2               3
# 2 2017-03-04       2017           3               5
# 3 2017-03-04       2017           3               5
# 4 2016-06-04       2016           6               5
#
# Sales by month:
# Sale_Month
# 1        2
# 2      443
# 3      678
# 4      949
# ...

# %% [markdown]
# ---
# ## Summary: Complete Preprocessing Pipeline
#
# Here's a complete example putting it all together:

# %%
# Start fresh
df_final = df.copy()

# 1. Handle missing values
df_final['Car'].fillna(df_final['Car'].median(), inplace=True)
df_final['YearBuilt'].fillna(df_final['YearBuilt'].median(), inplace=True)
df_final['BuildingArea'].fillna(df_final['BuildingArea'].median(), inplace=True)
df_final['CouncilArea'].fillna(df_final['CouncilArea'].mode()[0], inplace=True)

# 2. Feature engineering
df_final['Building_Age'] = 2024 - df_final['YearBuilt']
df_final['Price_per_Room'] = df_final['Price'] / df_final['Rooms']

# 3. Encode categoricals
df_final = pd.get_dummies(df_final, columns=['Type', 'Regionname'], drop_first=True)

# 4. Scale numerical features (for ML models)
from sklearn.preprocessing import StandardScaler
numerical_features = ['Rooms', 'Distance', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea']
scaler = StandardScaler()
df_final[numerical_features] = scaler.fit_transform(df_final[numerical_features])

print("Preprocessing complete!")
print(f"Final dataset shape: {df_final.shape}")
print(f"Missing values: {df_final.isnull().sum().sum()}")
print("\nFirst few rows of processed data:")
df_final.head()
# Out:
# Preprocessing complete!
# Final dataset shape: (13580, 31)
# Missing values: 0
#
# First few rows of processed data:
# C:\Users\liaor\AppData\Local\Temp\ipykernel_78480\2361971828.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_final['Car'].fillna(df_final['Car'].median(), inplace=True)
# C:\Users\liaor\AppData\Local\Temp\ipykernel_78480\2361971828.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# ---
# ---
# # Exercises
#
# Now it's your turn to practice! Work through these exercises using the techniques you've learned.

# %% [markdown]
# ### Exercise 1: Missing Value Analysis
#
# Calculate the **percentage** of missing values for each column in the original `df` dataset. Display only columns that have more than 5% missing values.
#
# **Hints:**
# - Use `.isnull().sum()` to count missing values
# - Divide by total rows: `len(df)`
# - Multiply by 100 for percentage
# - Filter using boolean indexing

# %%
# Exercise 1: Your code here
missing_percentages = ?    # Calculate percentage for each column
columns_with_high_missing = ?    # Filter for > 5%

print("Columns with >5% missing values:")
print(columns_with_high_missing)
# Out:
#   Cell In[49], line 2
#     missing_percentages = ?    # Calculate percentage for each column
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Exercise 2: Smart Missing Value Imputation
#
# Create a copy of `df` called `df_ex2`. For the `Car` column:
# 1. Calculate how many values are missing
# 2. Fill missing values with the **median** instead of mean
# 3. Verify that there are no more missing values in `Car`
#
# **Hint:** Use `.fillna()` with `inplace=True`

# %%
# Exercise 2: Your code here
df_ex2 = df.copy()

missing_count = ?    # Count missing values in Car
median_value = ?     # Calculate median
# Fill missing values here
?

print(f"Missing values before: {missing_count}")
print(f"Median value used: {median_value}")
print(f"Missing values after: {df_ex2['Car'].isnull().sum()}")

# %% [markdown]
# ### Exercise 3: Detect Outliers in Landsize
#
# Use the IQR method to detect outliers in the `Landsize` column:
# 1. Calculate Q1, Q3, and IQR
# 2. Calculate lower and upper bounds
# 3. Find how many properties have outlier land sizes
# 4. What's the largest landsize value?
#
# **Hint:** Review the IQR example for Price earlier in the notebook

# %%
# Exercise 3: Your code here
Q1 = ?    # 25th percentile
Q3 = ?    # 75th percentile
IQR = ?   # Interquartile range

lower_bound = ?
upper_bound = ?

outliers = ?    # Filter for outliers
max_landsize = ?    # Find maximum

print(f"Q1: {Q1}, Q3: {Q3}, IQR: {IQR}")
print(f"Outlier bounds: [{lower_bound:.2f}, {upper_bound:.2f}]")
print(f"Number of landsize outliers: {len(outliers)}")
print(f"Maximum landsize: {max_landsize} sq.m")

# %% [markdown]
# ### Exercise 4: Standardize Multiple Columns
#
# Create standardized versions of `Distance`, `Landsize`, and `BuildingArea` columns:
# 1. First, handle missing values in `BuildingArea` by filling with the median
# 2. Use `StandardScaler` to standardize all three columns at once
# 3. Add the scaled columns to the dataframe with suffix `_scaled`
# 4. Print the mean and std of each scaled column to verify
#
# **Hint:** You can pass multiple columns to `.fit_transform()` at once using `df[['col1', 'col2', 'col3']]`

# %%
# Exercise 4: Your code here
from sklearn.preprocessing import StandardScaler

df_ex4 = df.copy()

# Step 1: Fill missing values in BuildingArea
?

# Step 2-3: Create scaler and standardize
scaler = ?
df_ex4[['Distance_scaled', 'Landsize_scaled', 'BuildingArea_scaled']] = ?

# Step 4: Verify
print("Mean and Std of scaled columns:")
for col in ['Distance_scaled', 'Landsize_scaled', 'BuildingArea_scaled']:
    print(f"{col}: mean={df_ex4[col].mean():.10f}, std={df_ex4[col].std():.4f}")

# %% [markdown]
# ### Exercise 5: Normalize Price to [0, 1]
#
# Use `MinMaxScaler` to normalize the `Price` column to range [0, 1]:
# 1. Create a MinMaxScaler
# 2. Fit and transform the Price column
# 3. Add as new column `Price_normalized`
# 4. Find which house has the normalized price closest to 0.5
#
# **Hint:** Use `.iloc[(df['Price_normalized'] - 0.5).abs().argmin()]` to find closest to 0.5

# %%
# Exercise 5: Your code here
from sklearn.preprocessing import MinMaxScaler

df_ex5 = df.copy()

normalizer = ?
df_ex5['Price_normalized'] = ?

median_house = ?    # Find house closest to normalized price of 0.5

print(f"Normalized price range: [{df_ex5['Price_normalized'].min()}, {df_ex5['Price_normalized'].max()}]")
print(f"\nHouse with price closest to median (0.5):")
print(f"Address: {median_house['Address']}")
print(f"Actual Price: ${median_house['Price']:,.0f}")
print(f"Normalized Price: {median_house['Price_normalized']:.4f}")

# %% [markdown]
# ### Exercise 6: Label Encode Multiple Categorical Columns
#
# Apply label encoding to the `Method` and `SellerG` columns:
# 1. Create encoded versions with suffix `_encoded`
# 2. Display the unique original values and their encoded numbers for `Method`
#
# **Hint:** Use `.astype('category').cat.codes`

# %%
# Exercise 6: Your code here
df_ex6 = df.copy()

df_ex6['Method_encoded'] = ?
df_ex6['SellerG_encoded'] = ?

print("Method encoding mapping:")
print(df_ex6[['Method', 'Method_encoded']].drop_duplicates().sort_values('Method_encoded'))

print(f"\nNumber of unique sellers: {df_ex6['SellerG'].nunique()}")

# %% [markdown]
# ### Exercise 7: One-Hot Encode Property Type
#
# One-hot encode the `Type` column:
# 1. Use `pd.get_dummies()` with appropriate parameters
# 2. Use prefix `PropertyType`
# 3. Set `drop_first=True` to avoid multicollinearity
# 4. Count how many columns were created
#
# **Hint:** Compare the shape before and after encoding

# %%
# Exercise 7: Your code here
df_ex7 = df.copy()

original_cols = df_ex7.shape[1]
df_ex7 = ?    # One-hot encode Type column
new_cols = df_ex7.shape[1]

print(f"Columns before: {original_cols}")
print(f"Columns after: {new_cols}")
print(f"Columns added: {new_cols - original_cols}")

# Show the new columns
type_cols = [col for col in df_ex7.columns if col.startswith('PropertyType_')]
print(f"\nNew columns: {type_cols}")
print("\nSample values:")
print(df_ex7[type_cols].head(10))

# %% [markdown]
# ### Exercise 8: Feature Engineering - Price per Square Meter
#
# Create a new feature `Price_per_SqM` that represents the price per square meter of building area:
# 1. First, handle missing values in `BuildingArea` (use median)
# 2. Calculate `Price_per_SqM = Price / BuildingArea`
# 3. Find the property with the highest price per square meter
# 4. Find the average price per square meter by `Type`
#
# **Hint:** Use `.groupby()` for the average by Type

# %%
# Exercise 8: Your code here
df_ex8 = df.copy()

# Fill missing BuildingArea
?

# Create new feature
df_ex8['Price_per_SqM'] = ?

# Find highest
most_expensive_per_sqm = ?

# Average by type
avg_by_type = ?

print("Property with highest price per square meter:")
print(f"Address: {most_expensive_per_sqm['Address']}")
print(f"Price/SqM: ${most_expensive_per_sqm['Price_per_SqM']:,.2f}")
print(f"\nAverage price per square meter by property type:")
print(avg_by_type)

# %% [markdown]
# ### Exercise 9: Binning - Categorize Distance
#
# Create distance categories using `pd.cut()`:
# - 0-5 km: "City Center"
# - 5-10 km: "Inner Suburbs"
# - 10-20 km: "Outer Suburbs"
# - 20+ km: "Regional"
#
# Then:
# 1. Count how many properties are in each category
# 2. Calculate the average price for each distance category
# 3. Create a bar chart showing the count by category

# %%
# Exercise 9: Your code here
df_ex9 = df.copy()

# Define bins and labels
distance_bins = ?
distance_labels = ?

# Create categories
df_ex9['Distance_Category'] = ?

# Count by category
category_counts = ?

# Average price by category
avg_price_by_distance = ?

print("Properties by distance category:")
print(category_counts)
print("\nAverage price by distance category:")
print(avg_price_by_distance)

# Visualize
plt.figure(figsize=(10, 5))
category_counts.plot(kind='bar', color='coral')
plt.title('Number of Properties by Distance Category')
plt.xlabel('Distance Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 11: Handling Outliers
#
# Remove extreme price outliers using the IQR method:
# 1. Calculate IQR bounds for Price
# 2. Create a new dataframe `df_no_outliers` with outliers removed
# 3. Compare the mean and median before and after removing outliers
# 4. Create side-by-side box plots to visualize the difference
#
# **Hint:** Use boolean indexing to keep only rows within bounds

# %%
# Exercise 11: Your code here
df_ex11 = df.copy()

# Calculate IQR bounds
Q1 = ?
Q3 = ?
IQR = ?
lower = ?
upper = ?

# Remove outliers
df_no_outliers = ?

# Compare statistics
print("Before removing outliers:")
print(f"  Count: {len(df_ex11)}")
print(f"  Mean: ${df_ex11['Price'].mean():,.0f}")
print(f"  Median: ${df_ex11['Price'].median():,.0f}")

print("\nAfter removing outliers:")
print(f"  Count: {len(df_no_outliers)}")
print(f"  Mean: ${df_no_outliers['Price'].mean():,.0f}")
print(f"  Median: ${df_no_outliers['Price'].median():,.0f}")
print(f"  Removed: {len(df_ex11) - len(df_no_outliers)} rows")

# Visualize
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
sns.boxplot(data=df_ex11, y='Price', ax=axes[0])
axes[0].set_title('With Outliers')
sns.boxplot(data=df_no_outliers, y='Price', ax=axes[1])
axes[1].set_title('Without Outliers')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 12: Complete Preprocessing Pipeline
#
# Put it all together! Create a fully preprocessed dataset ready for machine learning:
#
# 1. Start with a fresh copy of `df`
# 2. Fill missing values appropriately for each column
# 3. Create at least 2 new engineered features
# 4. One-hot encode `Type` and `Regionname`
# 5. Standardize numerical columns: `Rooms`, `Distance`, `Bathroom`, `Car`
# 6. Remove rows where Price is missing
# 7. Print a summary of your final dataset
#
# **Challenge:** Make this pipeline as complete as possible!

# %%
# Exercise 12: Your code here
df_ex12 = df.copy()

# 1. Handle missing values
?

# 2. Feature engineering
?

# 3. One-hot encoding
?

# 4. Standardization
?

# 5. Remove missing prices
?

# Summary
print("=" * 50)
print("PREPROCESSING PIPELINE COMPLETE")
print("=" * 50)
print(f"Final shape: {df_ex12.shape}")
print(f"Missing values: {df_ex12.isnull().sum().sum()}")
print(f"\nColumn count by type:")
print(df_ex12.dtypes.value_counts())
print("\nFirst few rows:")
print(df_ex12.head())

# %% [markdown]
# ---
# ---
# # Data Exploration Questions
#
# Now that you know how to preprocess data, try exploring the dataset to answer these questions. You have **2 hours** to investigate as many as you can.
#
# **Instructions:**
# - Use cells below to explore each question
# - Apply preprocessing techniques as needed
# - Create visualizations to support your findings
# - Write conclusions in markdown cells
#
# ## Question 1: Property Type Analysis
#
# **Investigate:** How do different property types (house, unit, townhouse) compare in terms of:
# - Average price
# - Average number of rooms
# - Average landsize
# - Distribution across regions
#
# **Deliverables:**
# - Summary statistics table
# - At least 2 visualizations (e.g., bar charts, box plots)
# - Written conclusion about which property type offers the best value
#
# **Techniques to use:** Groupby, aggregation, visualization, statistical comparison

# %%
# Question 1: Your exploration here

# %% [markdown]
# ## Question 2: Distance vs Price Relationship
#
# **Investigate:** How does distance from the city center affect property prices?
# - Is there a linear relationship?
# - Are there "sweet spots" with good value?
# - Does the relationship differ by property type?
# - What's the price difference between city center (0-5km) and suburbs (10-20km)?
#
# **Deliverables:**
# - Scatter plot of Distance vs Price
# - Average price by distance category
# - Analysis by property type
# - Recommendation for budget-conscious buyers
#
# **Techniques to use:** Scatter plots, binning, correlation analysis, groupby

# %%
# Question 2: Your exploration here

# %% [markdown]
# ## Question 3: Building Age Impact
#
# **Investigate:** How does the age of a building affect its price and other characteristics?
# - What's the distribution of building ages?
# - Do older or newer buildings cost more?
# - Create age categories (new: <10 years, modern: 10-30, established: 30-50, heritage: 50+)
# - How does building area relate to age?
#
# **Deliverables:**
# - Histogram of building ages
# - Price comparison across age categories
# - Scatter plot of Age vs Price (colored by property type)
# - Analysis of renovation opportunities
#
# **Techniques to use:** Feature engineering, binning, correlation, visualization

# %%
# Question 3: Your exploration here

# %% [markdown]
# ---
# ## Summary
#
# Congratulations! You've learned comprehensive data preprocessing techniques:
#
# **Key Skills:**
# - ✅ Handling missing values (drop, fill, impute)
# - ✅ Detecting and handling outliers (IQR method)
# - ✅ Feature scaling (standardization and normalization)
# - ✅ Encoding categorical variables (label encoding, one-hot encoding)
# - ✅ Feature engineering (creating new features)
# - ✅ Data type conversions and date parsing
# - ✅ Complete preprocessing pipelines
